# %%
import pw2py as pw

# %% [markdown]
# ### How to create a qeinp object

# %%
# create an 'qeinp' object from a qe file
# specifying the prefix of the file will cause the code to check for both an input and output file (reading geo from output)
filename = 'relax'
inp = pw.qeinp.from_file(filename)

# %% [markdown]
# ### Attributes of the qeinp object

# %%
# qeinp is a subclass of atomgeo so everything we can do with atomgeo we can do with qeinp
print('-'*20, 'inp.ion', '-'*20)
print(inp.ion)          # ion names
print('-'*20, 'inp.pos_units', '-'*20)
print(inp.pos_units)    # units for the positions (crystal, angstrom, and bohr are supported)
print('-'*20, 'inp.pos', '-'*20)
print(inp.pos)          # xyz positions
print('-'*20, 'inp.par_units', '-'*20)
print(inp.par_units)    # units for the cell parameters (ibrav supported!)
print('-'*20, 'inp.par', '-'*20)
print(inp.par)          # cell parameters
# Out:
# -------------------- inp.ion --------------------
# ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Sn' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Sn']
# -------------------- inp.pos_units --------------------
# crystal
# -------------------- inp.pos --------------------
# [[ 3.18706896e-01  3.32943840e-01  9.17294076e-01]
#  [ 1.64760445e-01  4.85266868e-01  9.17896614e-01]
#  [ 4.85618459e-01  3.18969865e-01  8.27040790e-02]
#  [ 3.33001365e-01  1.39489770e-02  8.31115030e-02]
#  [ 1.80747575e-01  1.66387832e-01  8.33111260e-02]
#  [ 1.33658780e-02  1.79827584e-01  9.17061838e-01]
#  [ 1.55570743e-01  1.21630400e-03  2.50022038e-01]
#  [-3.59638800e-03  1.49503494e-01  2.49484301e-01]
#  [ 3.14306905e-01  4.85825629e-01  4.16873640e-01]
#  [ 1.65388263e-01  1.80281888e-01  4.15805919e-01]
#  [ 1.54575470e-02  3.35904742e-01  4.15840789e-01]
#  [ 3.42361485e-01  3.44993768e-01  2.49846665e-01]
#  [ 4.85554690e-01  1.66971522e-01  5.84511056e-01]
#  [ 3.28398240e-01  3.12398877e-01  5.82506590e-01]
#  [ 1.52468491e-01  1.52372013e-01  7.51076680e-01]
#  [-2.44124000e-04  3.47664995e-01  7.51197542e-01]
#  [ 3.47065421e-01  1.41213000e-04  7.50842718e-01]
#  [ 1.79960558e-01  1.33693700e-02  5.84176833e-01]
#  [ 1.65403485e-01  3.31771566e-01  2.06261370e-02]
#  [ 2.25975000e-04 -1.46372700e-03  1.44779449e-01]
#  [ 3.33281935e-01  1.66532690e-01  9.78274054e-01]
#  [-1.74369000e-04 -5.72413000e-04  8.55317241e-01]
#  [-1.35794800e-03 -3.51889000e-03  3.53530701e-01]
#  [ 3.28643899e-01  1.63338689e-01  4.80586158e-01]
#  [ 1.57798513e-01  3.27826296e-01  3.11442137e-01]
#  [ 3.33069539e-01  1.65176427e-01  1.86781941e-01]
#  [ 3.35442269e-01  1.69948719e-01  6.89590650e-01]
#  [ 1.66331121e-01  3.33422658e-01  8.13462833e-01]
#  [ 3.36282300e-03  2.65149800e-03  6.48303787e-01]
#  [ 1.66030689e-01  3.30505808e-01  5.23103675e-01]
#  [ 8.19530650e-01  3.33530471e-01  9.17033230e-01]
#  [ 6.66641242e-01  4.85884524e-01  9.17043571e-01]
#  [ 9.85516901e-01  3.18717736e-01  8.26893650e-02]
#  [ 8.32743246e-01  1.33507270e-02  8.35521640e-02]
#  [ 1.81307700e-03  5.02240049e-01  3.52146558e-01]
#  [ 3.26299671e-01  6.67416640e-01  4.81530335e-01]
#  [ 1.67323075e-01  8.34269520e-01  3.11721263e-01]
#  [ 3.31217552e-01  6.66162191e-01  1.86745481e-01]
#  [ 3.34132443e-01  6.64456518e-01  6.90271613e-01]
#  [ 1.65889653e-01  8.32989927e-01  8.11804298e-01]
#  [ 1.74430900e-03  5.01364280e-01  6.46924017e-01]
#  [ 1.67703900e-01  8.35821927e-01  5.21583906e-01]
#  [ 8.19769126e-01  8.34036201e-01  9.17307372e-01]
#  [ 6.66513854e-01  9.85584540e-01  9.17089065e-01]
#  [ 9.86807894e-01  8.18634038e-01  8.19590820e-02]
#  [ 8.33282215e-01  5.14006695e-01  8.30351480e-02]
#  [ 6.81969850e-01  6.67095243e-01  8.25353550e-02]
#  [ 5.14760202e-01  6.80776072e-01  9.17078397e-01]
#  [ 6.52403194e-01  4.96282315e-01  2.49914151e-01]
#  [ 4.97342339e-01  6.45709058e-01  2.45260674e-01]
#  [ 8.25406253e-01  9.94739841e-01  4.20055268e-01]
#  [ 6.74488343e-01  6.83369217e-01  4.17376369e-01]
#  [ 5.08201476e-01  8.31482472e-01  4.17292304e-01]
#  [ 8.58492234e-01  8.47536744e-01  2.48412891e-01]
#  [ 9.90181839e-01  6.67821187e-01  5.84126250e-01]
#  [ 8.37459504e-01  8.19972125e-01  5.83915291e-01]
#  [ 6.53497739e-01  6.53817865e-01  7.51364859e-01]
#  [ 5.00285651e-01  8.47653733e-01  7.50406103e-01]
#  [ 8.47961324e-01  4.99657486e-01  7.51069637e-01]
#  [ 6.91525224e-01  5.16480601e-01  5.82333067e-01]
#  [ 6.66498052e-01  8.33567284e-01  2.11660460e-02]
#  [ 4.99124776e-01  5.00727581e-01  1.38830054e-01]
#  [ 8.33501942e-01  6.66787897e-01  9.77966609e-01]
#  [ 4.99454868e-01  4.98995619e-01  8.52706655e-01]
#  [ 4.99417736e-01  5.01057981e-01  3.51687897e-01]
#  [ 8.41412328e-01  6.61148645e-01  4.81183325e-01]
#  [ 6.73878898e-01  8.44417536e-01  3.02710401e-01]
#  [ 8.36084651e-01  6.67472651e-01  1.86663021e-01]
#  [ 8.29514244e-01  6.62630381e-01  6.89490375e-01]
#  [ 6.66535088e-01  8.32676328e-01  8.12927958e-01]
#  [ 4.96279691e-01  4.97175502e-01  6.45581647e-01]
#  [ 6.67955184e-01  8.36954283e-01  5.17855385e-01]]
# -------------------- inp.par_units --------------------
# angstrom
# -------------------- inp.par --------------------
# [[10.26519168  0.          0.        ]
#  [-5.13259584  8.88991754  0.        ]
#  [ 0.          0.         13.99123349]]

# %% [markdown]
# ### QE namelist

# %%
# but now we have information of the qe namelist!
print(inp.nml)  # namelists include control, system, electrons, etc.
# Out:
# &control
#     calculation = 'relax'
#     prefix = 'fe2o3'
#     wf_collect = .true.
# /
#
# &system
#     ibrav = 0
#     nat = 120
#     ntyp = 4
#     ecutwfc = 40.0
#     ecutrho = 240.0
#     occupations = 'smearing'
#     smearing = 'mp'
#     degauss = 0.005
#     nspin = 2
#     starting_magnetization(2:3) = -0.5, 0.5
#     lda_plus_u = .true.
#     hubbard_u(2:3) = 4.3, 4.3
# /
#
# &electrons
#     mixing_beta = 0.3
#     conv_thr = 1e-07
#     electron_maxstep = 200
# /
#
# &ions
# /

# %%
# the easiest way to access the keys of the namelist is like this:
print(inp.nml.ibrav)
print(inp.nml.mixing_beta)

# but you can also do this
print(inp.nml['system']['ibrav'])
print(inp.nml['electrons']['mixing_beta'])
# Out:
# 0
# 0.3
# 0
# 0.3

# %%
# let's make an nscf calculation
inp.nml.calculation = 'nscf'
inp.nml.nbnd = 1000
inp.kpt = [[4, 4, 4], [0, 0, 0]]

# and write the file
inp.write_file('nscf.in')

# %% [markdown]
# ### QE Cards

# %%
# let's refresh things
inp = pw.qeinp.from_file(filename)

# %%
# we can also see all the cards of the input file
print(inp.card)  # cards include ATOMIC_POSITIONS, ATOMIC_SPECIES, K_POINTS, etc.
print(inp.card.ATOMIC_SPECIES)
# Out:
# {'CELL_PARAMETERS': 'angstrom', 'ATOMIC_SPECIES': {'O': [1.0, 'o_pbe_v1.2.uspp.F.UPF'], 'Fe1': [1.0, 'fe_pbe_v1.5.uspp.F.UPF'], 'Fe2': [1.0, 'fe_pbe_v1.5.uspp.F.UPF'], 'Sn': [1.0, 'sn_pbe_v1.4.uspp.F.UPF']}, 'K_POINTS': 'automatic', 'ATOMIC_POSITIONS': 'crystal'}
# {'O': [1.0, 'o_pbe_v1.2.uspp.F.UPF'], 'Fe1': [1.0, 'fe_pbe_v1.5.uspp.F.UPF'], 'Fe2': [1.0, 'fe_pbe_v1.5.uspp.F.UPF'], 'Sn': [1.0, 'sn_pbe_v1.4.uspp.F.UPF']}

# %%
# if we replace all instances of Sn with Zr
inp.replace_ion('Sn', 'Zr')
# the ATOMIC_SPECIES will updated automatically!
print(inp.card.ATOMIC_SPECIES)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e8a4009eb94c> in <module>
#       1 # if we replace all instances of Sn with Zr
# ----> 2 inp.replace_ion('Sn', 'Zr')
#       3 # the ATOMIC_SPECIES will updated automatically!
#       4 print(inp.card.ATOMIC_SPECIES)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/qeinp/methods.py in replace_ion(self, old_ion, new_ion)
#     184     self.nml['system']['ntyp'] = self.ntyp
#     185
# --> 186     _fix_species(self)
#     187
#     188
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/qeinp/methods.py in _fix_species(self)
#      33
#      34     # first add ion missing from atomic species
# ---> 35     pseudos = _pseudos_from_ATOMIC_SPECIES(self)
#      36     for ion in attr_ion:
#      37         if ion not in card_ion:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/qeinp/methods.py in _pseudos_from_ATOMIC_SPECIES(self)
#      18         pseudos = load_pseudo_dict()[library]
#      19     else:
# ---> 20         pseudos = load_pseudo_dict()[library][xc_type]
#      21
#      22     return pseudos
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/_common/pseudos.py in load_pseudo_dict()
#     101     '''
#     102     if not os.path.exists(dump_file):
# --> 103         main()
#     104     with open(dump_file, 'rb') as f:
#     105         pseudos = pkl.load(f)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/_common/pseudos.py in main()
#     136
#     137 def main():
# --> 138     pseudos = generate_pseudo_dict()
#     139     with open(dump_file, 'wb') as f:
#     140         pkl.dump(pseudos, f)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pw2py/_common/pseudos.py in generate_pseudo_dict(pseudo_path)
#      28     # path to pseudopotential files
#      29     if pseudo_path == 'check environment':
# ---> 30         pseudo_path = os.environ['ESPRESSO_PSEUDO']
#      31     if not os.path.isdir(pseudo_path):
#      32         raise FileNotFoundError('Provide the value of pseudo_path with option -p')
#
# ~/opt/anaconda3/lib/python3.8/os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'ESPRESSO_PSEUDO'

# %%
# print our full input file
print(inp)

# save to a new input file
inp.write_file('zr.in')
# Out:
# &control
#     calculation = 'relax'
#     prefix = 'fe2o3'
#     wf_collect = .true.
# /
#
# &system
#     ibrav = 0
#     nat = 120
#     ntyp = 4
#     ecutwfc = 40.0
#     ecutrho = 240.0
#     occupations = 'smearing'
#     smearing = 'mp'
#     degauss = 0.005
#     nspin = 2
#     starting_magnetization(2:3) = -0.5, 0.5
#     lda_plus_u = .true.
#     hubbard_u(2:3) = 4.3, 4.3
# /
#
# &electrons
#     mixing_beta = 0.3
#     conv_thr = 1e-07
#     electron_maxstep = 200
# /
#
# &ions
# /
#
# ATOMIC_SPECIES
#     O        1.0000  o_pbe_v1.2.uspp.F.UPF
#     Fe1      1.0000  fe_pbe_v1.5.uspp.F.UPF
#     Fe2      1.0000  fe_pbe_v1.5.uspp.F.UPF
#     Sn       1.0000  sn_pbe_v1.4.uspp.F.UPF
#
# CELL_PARAMETERS angstrom
#         10.265191682       0.000000000       0.000000000
#         -5.132595840       8.889917538       0.000000000
#          0.000000000       0.000000000      13.991233495
#
# ATOMIC_POSITIONS crystal
#     O           0.318706896       0.332943840       0.917294076
#     O           0.164760445       0.485266868       0.917896614
#     O           0.485618459       0.318969865       0.082704079
#     O           0.333001365       0.013948977       0.083111503
#     O           0.180747575       0.166387832       0.083311126
#     O           0.013365878       0.179827584       0.917061838
#     O           0.155570743       0.001216304       0.250022038
#     O          -0.003596388       0.149503494       0.249484301
#     O           0.314306905       0.485825629       0.416873640
#     O           0.165388263       0.180281888       0.415805919
#     O           0.015457547       0.335904742       0.415840789
#     O           0.342361485       0.344993768       0.249846665
#     O           0.485554690       0.166971522       0.584511056
#     O           0.328398240       0.312398877       0.582506590
#     O           0.152468491       0.152372013       0.751076680
#     O          -0.000244124       0.347664995       0.751197542
#     O           0.347065421       0.000141213       0.750842718
#     O           0.179960558       0.013369370       0.584176833
#     Fe1         0.165403485       0.331771566       0.020626137
#     Fe2         0.000225975      -0.001463727       0.144779449
#     Fe1         0.333281935       0.166532690       0.978274054
#     Fe2        -0.000174369      -0.000572413       0.855317241
#     Fe1        -0.001357948      -0.003518890       0.353530701
#     Fe2         0.328643899       0.163338689       0.480586158
#     Fe1         0.157798513       0.327826296       0.311442137
#     Fe2         0.333069539       0.165176427       0.186781941
#     Fe1         0.335442269       0.169948719       0.689590650
#     Fe2         0.166331121       0.333422658       0.813462833
#     Fe1         0.003362823       0.002651498       0.648303787
#     Fe2         0.166030689       0.330505808       0.523103675
#     O           0.819530650       0.333530471       0.917033230
#     O           0.666641242       0.485884524       0.917043571
#     O           0.985516901       0.318717736       0.082689365
#     O           0.832743246       0.013350727       0.083552164
#     O           0.680666866       0.167148693       0.082002701
#     O           0.653497739       0.653817865       0.751364859
#     O           0.500285651       0.847653733       0.750406103
#     O           0.847961324       0.499657486       0.751069637
#     O           0.691525224       0.516480601       0.582333067
#     Fe1         0.666498052       0.833567284       0.021166046
#     Fe2         0.499124776       0.500727581       0.138830054
#     Fe1         0.833501942       0.666787897       0.977966609
#     Fe2         0.499454868       0.498995619       0.852706655
#     Zr          0.499417736       0.501057981       0.351687897
#     Fe2         0.841412328       0.661148645       0.481183325
#     Fe1         0.673878898       0.844417536       0.302710401
#     Fe2         0.836084651       0.667472651       0.186663021
#     Fe1         0.829514244       0.662630381       0.689490375
#     Fe2         0.666535088       0.832676328       0.812927958
#     Fe1         0.496279691       0.497175502       0.645581647
#     Zr          0.667955184       0.836954283       0.517855385
#
# K_POINTS automatic
#     2  2  2    0  0  0

# %% [markdown]
# ### Read the help menu

# %%
help(inp)
# Out:
# Help on qeinp in module pw2py.qeinp object:
#
# class qeinp(pw2py.atomgeo.atomgeo)
#  |  qeinp(nml, card, ion, par, par_units, pos, pos_units, if_pos, kpt)
#  |
#  |  class for quantum espresso input file
#  |      qedict = dictionary of namelists (nml), ATOMIC_SPECIES, CELL_PARAMETERS, ATOMIC_POSITIONS, and K_POINTS
#  |      par = CELL_PARAMETERS data
#  |      ion = ATOMIC_POSITIONS ions data
#  |      pos = ATOMIC_POSITIONS position data
#  |      if_pos = ATOMIC_POSITIONS if_pos data
#  |      kpt = K_POINTS data
#  |
#  |  Method resolution order:
#  |      qeinp
#  |      pw2py.atomgeo.atomgeo
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, nml, card, ion, par, par_units, pos, pos_units, if_pos, kpt)
#  |      initialize qeinp object
#  |
#  |  __repr__(self)
#  |
#  |  __str__(self)
#  |
#  |  add_atom(self, atoms, if_pos=[1, 1, 1])
#  |      append atoms to self.ion and self.pos
#  |      atoms = ion, pos
#  |
#  |      calls atomgeo.add_atom(self, atoms)
#  |
#  |  build_supercell(self, P, inplace=True, if_pos=[1, 1, 1])
#  |      Build supercell
#  |
#  |      Only simple supercells are implemented wherein the shape of the cell cannot be changed
#  |
#  |      P (np.array, int, size = (3,1))
#  |
#  |  load_geo(self, geo, load='default', keep_if_pos=False)
#  |      return new qeinp object with geometry from geo
#  |
#  |      load (str)
#  |          -- can be default, cell, or atoms
#  |      keep_if_pos (bool)
#  |          -- if true, and geo does not have attribute 'if_pos' then keep if_pos of self
#  |
#  |  remove_indices(self, indices)
#  |      remove list of indices from self.ion and self.pos
#  |
#  |      calls atomgeo.remove_indices(self, indices)
#  |
#  |  replace_ion(self, old_ion, new_ion)
#  |      replace ion species 'old_ion' with 'new_ion'
#  |
#  |      calls atomgeo.replace_ion(self, old_ion, new_ion)
#  |
#  |  to_atomgeo(self)
#  |      Return atomgeo object
#  |
#  |  to_string(self)
#  |      convert qeinp to string
#  |
#  |  write_file(self, filename, **kwargs)
#  |      create qeinput object from file
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_file(filename, is_prefix=None) from builtins.type
#  |      create qeinp object from file
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  ntyp
#  |      return number of atoms
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  ibrav
#  |      return value of self.nml.ibrav
#  |
#  |  if_pos
#  |      return value of atomgeo._if_pos
#  |
#  |  ion
#  |
#  |  kpt
#  |      return value of qeinp._kpt
#  |
#  |  par
#  |
#  |  par_units
#  |
#  |  pos
#  |
#  |  pos_units
#  |      return value of atomgeo._pos_units
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pw2py.atomgeo.atomgeo:
#  |
#  |  calc_dQ(self, geo, pos_units='angstrom', mass_units='au', suppress_warnings=False)
#  |      Calculate deltaQ = sqrt(sum_i (deltaQ_i)**2)
#  |
#  |      returns np.sqrt(np.sum(self.calc_dQ2(geo)))
#  |
#  |  calc_dQ2(self, geo, pos_units='angstrom', mass_units='au', suppress_warnings=False)
#  |      Calculate deltaQ2 = mass_i * (deltaR_i)**2
#  |
#  |      (deltaR_i)**2 = calc_dR2(self, geo)
#  |
#  |  calc_dR(self, geo, units='angstrom', suppress_warnings=False)
#  |      Calculate deltaR_i = self.pos - geo.pos
#  |
#  |      if necessary creates copies of self and geo to convert them to angstrom
#  |
#  |  calc_dR2(self, geo, units='angstrom', suppress_warnings=False)
#  |      Calculate deltaR2_i = (self.pos - geo.pos)**2
#  |
#  |      returns np.sum(np.power(self.calc_dR(geo), 2), axis=1)
#  |
#  |  calc_distance(self, x: numpy.ndarray) -> float
#  |      Calculate the distance from self.pos and vector x, considering boundary conditions
#  |
#  |  composition(self) -> dict
#  |      Return the composition of ions
#  |
#  |  dQ_field_2_xsf(self, geo, filename, suppress_warnings=False)
#  |      Calculate deltaQ_i = sqrt(mass_i) * (self.pos_i - geo.pos_i)
#  |
#  |      Write to xsf file (filename)
#  |
#  |  elements(self)
#  |      return elemental names of each ion (stripping number i.e. 'Fe2' will return 'Fe')
#  |
#  |  mass(self, units='au')
#  |      return mass of each ion
#  |
#  |      TODO implement different unit conversions, currently will only return au
#  |
#  |  nearest_neighbor(self, site_id, N=1, include_site=False, return_type='index', with_boundaries=True)
#  |      Calculate nearest neighbors of site_id
#  |
#  |      input
#  |      ----
#  |          site_id (int)
#  |              - index (base 0) of the site to calculate nearest neighbors of
#  |          N (optional) (int)
#  |              - number of neighbors to return data for (note if include_site=True,
#  |                  total number of elements returned is N+1, otherwise it is N)
#  |          include_site (optional) (bool)
#  |              - if True than the site_id atom is returned as well, default is False
#  |          return_type (optional) (str)
#  |              - possible options include:
#  |                  - 'df': return dataframe with columns = ['ion', 'pos', 'dist']
#  |                  - 'index': list of indices (ints)
#  |                  - 'dist': list of distances in angstrom (floats)
#  |                  - 'atoms': list of dictionaries with keys 'ion' and 'pos' (dicts)
#  |          with_boundaries (optional) (bool)
#  |              - if True than boundary conditions are considered when computing distances
#  |
#  |      returns
#  |      ----
#  |          see return_type above
#  |
#  |  shift_pos_to_unit(self, inplace=True)
#  |      Shift all atoms to be within the unit cell dimensions (i.e. between 0<1 in crystal)
#  |
#  |  sort_ions(self, inplace=False)
#  |      sort ions into categories and reorder corresponding positions
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from pw2py.atomgeo.atomgeo:
#  |
#  |  from_save(prefix: pw2py.qesave.qesave, path: str = '.', version: str = None) from builtins.type
#  |      generate atomgeo object qe savefolder
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from pw2py.atomgeo.atomgeo:
#  |
#  |  atoms
#  |      return atoms as dictionary with keys as ion names and values as positions
#  |
#  |  nat
#  |      return number of atoms
#  |
#  |  rec
#  |      return value of atomgeo._rec
#  |
#  |  vol
#  |      return volume of the cell
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pw2py.atomgeo.atomgeo:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
