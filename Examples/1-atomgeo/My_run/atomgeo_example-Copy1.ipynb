# %%
import pw2py as pw

# %% [markdown]
# ### How to create an atomgeo object

# %%
# create an 'atomgeo' object from a qe file (can also read vasp, xyz, xsf, jdftx)
filename = '../relax.out'
geo = pw.atomgeo.from_file(filename)

# %% [markdown]
# ### Attributes of the atomgeo object

# %%
# print some things about the geometry
print('-'*20, 'geo.ion', '-'*20)
print(geo.ion)          # ion names
print('-'*20, 'geo.pos_units', '-'*20)
print(geo.pos_units)    # units for the positions (crystal, angstrom, and bohr are supported)
print('-'*20, 'geo.pos', '-'*20)
print(geo.pos)          # xyz positions
print('-'*20, 'geo.par_units', '-'*20)
print(geo.par_units)    # units for the cell parameters (ibrav supported!)
print('-'*20, 'geo.par', '-'*20)
print(geo.par)          # cell parameters
# Out:
# -------------------- geo.ion --------------------
# ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Sn' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Sn']
# -------------------- geo.pos_units --------------------
# crystal
# -------------------- geo.pos --------------------
# [[ 3.18706896e-01  3.32943840e-01  9.17294076e-01]
#  [ 1.64760445e-01  4.85266868e-01  9.17896614e-01]
#  [ 4.85618459e-01  3.18969865e-01  8.27040790e-02]
#  [ 3.33001365e-01  1.39489770e-02  8.31115030e-02]
#  [ 1.80747575e-01  1.66387832e-01  8.33111260e-02]
#  [ 1.33658780e-02  1.79827584e-01  9.17061838e-01]
#  [ 1.55570743e-01  1.21630400e-03  2.50022038e-01]
#  [-3.59638800e-03  1.49503494e-01  2.49484301e-01]
#  [ 3.14306905e-01  4.85825629e-01  4.16873640e-01]
#  [ 1.65388263e-01  1.80281888e-01  4.15805919e-01]
#  [ 1.54575470e-02  3.35904742e-01  4.15840789e-01]
#  [ 3.42361485e-01  3.44993768e-01  2.49846665e-01]
#  [ 4.85554690e-01  1.66971522e-01  5.84511056e-01]
#  [ 3.28398240e-01  3.12398877e-01  5.82506590e-01]
#  [ 1.52468491e-01  1.52372013e-01  7.51076680e-01]
#  [-2.44124000e-04  3.47664995e-01  7.51197542e-01]
#  [ 3.47065421e-01  1.41213000e-04  7.50842718e-01]
#  [ 1.79960558e-01  1.33693700e-02  5.84176833e-01]
#  [ 1.65403485e-01  3.31771566e-01  2.06261370e-02]
#  [ 2.25975000e-04 -1.46372700e-03  1.44779449e-01]
#  [ 3.33281935e-01  1.66532690e-01  9.78274054e-01]
#  [-1.74369000e-04 -5.72413000e-04  8.55317241e-01]
#  [-1.35794800e-03 -3.51889000e-03  3.53530701e-01]
#  [ 3.28643899e-01  1.63338689e-01  4.80586158e-01]
#  [ 1.57798513e-01  3.27826296e-01  3.11442137e-01]
#  [ 3.33069539e-01  1.65176427e-01  1.86781941e-01]
#  [ 3.35442269e-01  1.69948719e-01  6.89590650e-01]
#  [ 1.66331121e-01  3.33422658e-01  8.13462833e-01]
#  [ 3.36282300e-03  2.65149800e-03  6.48303787e-01]
#  [ 1.66030689e-01  3.30505808e-01  5.23103675e-01]
#  [ 8.19530650e-01  3.33530471e-01  9.17033230e-01]
#  [ 6.66641242e-01  4.85884524e-01  9.17043571e-01]
#  [ 9.85516901e-01  3.18717736e-01  8.26893650e-02]
#  [ 1.79115082e+00  5.74030028e+00  3.43149936e+00]
#  [ 3.36735583e+00  8.84315516e+00  5.87709134e+00]
#  [ 3.41629413e+00  6.07509599e+00  5.83961023e+00]
#  [ 9.49122087e-01  7.39181061e+00  5.83843406e+00]
#  [ 4.46252377e+00  7.53453176e+00  3.47560276e+00]
#  [ 6.73675013e+00  5.93687528e+00  8.17264675e+00]
#  [ 4.38809682e+00  7.28948457e+00  8.16969518e+00]
#  [ 3.35249670e+00  5.81238690e+00  1.05125212e+01]
#  [ 7.84864080e-01  7.53557179e+00  1.04991070e+01]
#  [ 6.13994560e+00  4.44191385e+00  1.05083907e+01]
#  [ 4.44775279e+00  4.59146995e+00  8.14755791e+00]
#  [ 2.56336629e+00  7.41034442e+00  2.96139092e-01]
#  [ 2.55357920e+00  4.45142690e+00  1.94240370e+00]
#  [ 5.13370442e+00  5.92768942e+00  1.36829592e+01]
#  [ 2.56585712e+00  4.43602990e+00  1.19304179e+01]
#  [ 2.55489068e+00  4.45436413e+00  4.92054748e+00]
#  [ 5.24385005e+00  5.87755693e+00  6.73234825e+00]
#  [ 2.58344213e+00  7.50680226e+00  4.23529190e+00]
#  [ 5.15670185e+00  5.93377683e+00  2.61164591e+00]
#  [ 5.11410878e+00  5.89072945e+00  9.64682083e+00]
#  [ 2.56831938e+00  7.40242389e+00  1.13738649e+01]
#  [ 2.54260524e+00  4.41984921e+00  9.03248356e+00]
#  [ 2.56093993e+00  7.44045456e+00  7.24543561e+00]]

# %%
# replace all instances of Sn with Zr
geo.replace_ion('Sn', 'Zr')
print(geo.ion)
# Out:
# ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Zr' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Fe2' 'Fe1' 'Zr']

# %%
# Build supercell
P=(3,3,1)
geo.build_supercell(P)
print(geo.ion)
# Out:
# ['O' 'O' 'O' ... 'Fe2' 'Fe1' 'Zr']

# %%
# calculate 20 nearest neighbors of atom120 (careful python is base 0 so input 119)
df = geo.nearest_neighbor(119, return_type='df', N=20, include_site=True)
df.to_csv('neighbors.csv')  # write to csv file
print(df.iloc[1:7]) # print the first 6 nearest neighbors bonded to atom120
# Out:
#     ion                                                pos      dist
# 72    O  [1.496766860729326, 5.962536767395871, 8.13244...  2.025707
# 167   O  [1.7468664668390597, 9.078003132426542, 8.1718...  2.050021
# 103   O  [4.388096816781683, 7.28948457470863, 8.169695...  2.053180
# 98    O  [3.367355832767525, 8.843155158253232, 5.87709...  2.119019
# 99    O  [3.4162941278113057, 6.075095987137629, 5.8396...  2.138266
# 100   O  [0.9491220873952049, 7.391810610372396, 5.8384...  2.140088

# %%
geo.mass
# Out:
# <bound method mass of atomgeo(ion = array(['O', 'O', 'O', ..., 'Fe2', 'Fe1', 'Zr'], dtype=object),par = array([[ 30.79557505,   0.        ,   0.        ],
#        [-15.39778752,  26.66975261,   0.        ],
#        [  0.        ,   0.        ,  13.99123349]]),pos = array([[ 1.56272121,  2.95984328, 12.8340756 ],
#        [-0.79938116,  4.31398244, 12.84250585],
#        [ 3.34782316,  2.8356158 ,  1.15713208],
#        ...,
#        [12.83351107, 25.18225897, 11.37386487],
#        [12.80779693, 22.19968429,  9.03248356],
#        [12.82613161, 25.22028963,  7.24543561]]),par_units = 'angstrom',pos_units = 'angstrom')>

# %% [markdown]
# ### Write the geo to a new file

# %%
# write some new file formats (will use extension but you can also use the ftype keyword)
geo.write_file('3x3x1.vasp')
geo.write_file('3x3x1.xsf')
geo.write_file('3x3x1.in',ftype='qeinp')

# %% [markdown]
# ### Read the help menu

# %%
help(geo)
# Out:
# Help on atomgeo in module pw2py.atomgeo object:
#
# class atomgeo(builtins.object)
#  |  atomgeo(ion=None, par=None, pos=None, par_units=None, pos_units=None)
#  |
#  |  class for atomic geometry
#  |
#  |  Suggested to make object from file:
#  |  -----
#  |  geo = atomgeo.from_file(filename, ftype='auto')
#  |
#  |  Attributes:
#  |  -----
#  |
#  |  par (np.array, float, shape = (3,3))
#  |      - cell parameters
#  |
#  |  par_units (str)
#  |      - units of par, acceptable values include 'angstrom', 'bohr', 'alat'
#  |
#  |  nat (int)
#  |      - number of atoms
#  |
#  |  ion (list, str)
#  |      - list of atom/ion names (QE format)
#  |
#  |  pos (np.array, float, shape = (nat, 3))
#  |      - atomic positions
#  |
#  |  pos_units (str)
#  |      - units of pos, acceptable values include 'angstrom', 'bohr', 'crystal', 'alat'
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, ion=None, par=None, pos=None, par_units=None, pos_units=None)
#  |      initialize atomgeo instance
#  |
#  |  __repr__(self)
#  |      define atomgeo representation (str)
#  |
#  |  __str__(self, ftype='qeinp', sort=True)
#  |      default str method of atomgeo
#  |
#  |  add_atom(self, atoms)
#  |      append atoms to self.ion and self.pos
#  |      atoms = ion, pos
#  |
#  |  build_supercell(self, P, inplace=True)
#  |      Build supercell
#  |
#  |      Only simple supercells are implemented wherein the shape of the cell cannot be changed
#  |
#  |      P (np.array, int, size = (3,1))
#  |
#  |  calc_dQ(self, geo, pos_units='angstrom', mass_units='au', suppress_warnings=False)
#  |      Calculate deltaQ = sqrt(sum_i (deltaQ_i)**2)
#  |
#  |      returns np.sqrt(np.sum(self.calc_dQ2(geo)))
#  |
#  |  calc_dQ2(self, geo, pos_units='angstrom', mass_units='au', suppress_warnings=False)
#  |      Calculate deltaQ2 = mass_i * (deltaR_i)**2
#  |
#  |      (deltaR_i)**2 = calc_dR2(self, geo)
#  |
#  |  calc_dR(self, geo, units='angstrom', suppress_warnings=False)
#  |      Calculate deltaR_i = self.pos - geo.pos
#  |
#  |      if necessary creates copies of self and geo to convert them to angstrom
#  |
#  |  calc_dR2(self, geo, units='angstrom', suppress_warnings=False)
#  |      Calculate deltaR2_i = (self.pos - geo.pos)**2
#  |
#  |      returns np.sum(np.power(self.calc_dR(geo), 2), axis=1)
#  |
#  |  calc_distance(self, x: numpy.ndarray) -> float
#  |      Calculate the distance from self.pos and vector x, considering boundary conditions
#  |
#  |  composition(self) -> dict
#  |      Return the composition of ions
#  |
#  |  dQ_field_2_xsf(self, geo, filename, suppress_warnings=False)
#  |      Calculate deltaQ_i = sqrt(mass_i) * (self.pos_i - geo.pos_i)
#  |
#  |      Write to xsf file (filename)
#  |
#  |  elements(self)
#  |      return elemental names of each ion (stripping number i.e. 'Fe2' will return 'Fe')
#  |
#  |  mass(self, units='au')
#  |      return mass of each ion
#  |
#  |      TODO implement different unit conversions, currently will only return au
#  |
#  |  nearest_neighbor(self, site_id, N=1, include_site=False, return_type='index', with_boundaries=True)
#  |      Calculate nearest neighbors of site_id
#  |
#  |      input
#  |      ----
#  |          site_id (int)
#  |              - index (base 0) of the site to calculate nearest neighbors of
#  |          N (optional) (int)
#  |              - number of neighbors to return data for (note if include_site=True,
#  |                  total number of elements returned is N+1, otherwise it is N)
#  |          include_site (optional) (bool)
#  |              - if True than the site_id atom is returned as well, default is False
#  |          return_type (optional) (str)
#  |              - possible options include:
#  |                  - 'df': return dataframe with columns = ['ion', 'pos', 'dist']
#  |                  - 'index': list of indices (ints)
#  |                  - 'dist': list of distances in angstrom (floats)
#  |                  - 'atoms': list of dictionaries with keys 'ion' and 'pos' (dicts)
#  |          with_boundaries (optional) (bool)
#  |              - if True than boundary conditions are considered when computing distances
#  |
#  |      returns
#  |      ----
#  |          see return_type above
#  |
#  |  remove_indices(self, indices)
#  |      remove list of indices from self.ion and self.pos
#  |
#  |  replace_ion(self, old_ion, new_ion)
#  |      replace ion species 'old_ion' with 'new_ion'
#  |
#  |  shift_pos_to_unit(self, inplace=True)
#  |      Shift all atoms to be within the unit cell dimensions (i.e. between 0<1 in crystal)
#  |
#  |  sort_ions(self, inplace=False)
#  |      sort ions into categories and reorder corresponding positions
#  |
#  |  to_string(self, ftype='qeinp', sort=True)
#  |      convert atomgeo to str (default is qeinp format)
#  |
#  |      sort = False, then vasp output is not sorted first, may fail!!
#  |
#  |  write_file(self, filename, ftype='auto', sort=True)
#  |      write atomgeo to file (QE format)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_file(filename, ftype='auto', xyz_par=20) from builtins.type
#  |      generate atomgeo object from file
#  |
#  |      input
#  |      ---
#  |      filename (str)
#  |          - name/path to file to be read
#  |
#  |      ftype (str)
#  |          - specify filetype otherwise ftype='auto' will use filename to detect file type
#  |          - acceptable values: ['auto', 'vasp', 'qeinp', 'qeout', 'jdftx', 'xsf', 'xyz']
#  |
#  |      xyz_par (float)
#  |          - optional, only used when reading from xyz, par is set to a box of with dimension xyz_par in angstrom
#  |
#  |      returns
#  |      ---
#  |      atomgeo (atomgeo object)
#  |
#  |      notes
#  |      ---
#  |      reads geometry file (filename) using the ..functions.read_geo method
#  |
#  |  from_save(prefix: pw2py.qesave.qesave, path: str = '.', version: str = None) from builtins.type
#  |      generate atomgeo object qe savefolder
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  atoms
#  |      return atoms as dictionary with keys as ion names and values as positions
#  |
#  |  nat
#  |      return number of atoms
#  |
#  |  rec
#  |      return value of atomgeo._rec
#  |
#  |  vol
#  |      return volume of the cell
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ion
#  |      return value of atomgeo._ion
#  |
#  |  par
#  |      return value of atomgeo._par
#  |
#  |  par_units
#  |      return value of atomgeo._par_units
#  |
#  |  pos
#  |      return value of atomgeo._pos
#  |
#  |  pos_units
#  |      return value of atomgeo._pos_units
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __slotnames__ = []
